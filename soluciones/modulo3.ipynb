# %% [markdown]
# MÓDULO 3: PROPIEDADES STRING 2

# %%
kaiku = "Tierra mojada, mis recuerdos de viaje entre las lluvias"
palabra = kaiku.find("agua")
print(palabra)
# Out:
# -1

# %% [markdown]
# MÓDULO 3: PROPIEDADES STRING 3

# %%
texto = "electroencefalografista"
longitud=len(texto)

print(longitud)
# Out:
# 23

# %% [markdown]
# MÓDULO 3: MÉTODO ÍNDEX 3

# %%
frase = "En teoría, la teoría y la práctica son los mismos. En la práctica, no lo son."
indice = frase.rindex("práctica")
print(indice)
# Out:
# 57

# %% [markdown]
# MÓDULO 3: MÉTODO STRING 2

# %%
lista_palabras = ["La","legibilidad","cuenta."]
palabras_juntas = " ".join(lista_palabras)
print(palabras_juntas)
# Out:
# La legibilidad cuenta.

# %% [markdown]
# MÓDULO 3: MÉTODO STRING 3

# %%
frase = "Si la implementación es difícil de explicar, puede que sea una mala idea."
reemplazar1 = frase.replace("difícil", "fácil")
reemplazar1 = frase.replace("mala", "buena")
print(reemplazar1)
# Out:
# Si la implementación es difícil de explicar, puede que sea una buena idea.

# %% [markdown]
# MÓDULO 3: LISTAS 2

# %%
medios_transporte = ["avión", "auto", "barco", "bicicleta"]
medios_transporte.append("motocicleta")
print(medios_transporte)
# Out:
# ['avión', 'auto', 'barco', 'bicicleta', 'motocicleta']

# %% [markdown]
# MÓDULO 3: LISTAS 3

# %%
frutas = ["manzana", "banana", "mango", "cereza", "sandía"]
eliminado = frutas.pop(2)
print(frutas)
print(eliminado)
# Out:
# ['manzana', 'banana', 'cereza', 'sandía']
# mango

# %% [markdown]
# MÓDULO 3: DICCIONARIOS 1 Crea un diccionario llamado mi_dic que almacene la siguiente información de una persona:
#
# nombre: Karen
#
# apellido: Jurgens
#
# edad: 35
#
# ocupacion: Periodista
#
#
# Los nombres de las claves y valores deben ser iguales a la consigna.

# %%
mi_dic = {'nombre': 'Karen', 'apellido': 'Jurgens', 'edad': 35, 'ocupacion':'periodista'}
print(type(mi_dic))
# Out:
# <class 'dict'>

# %% [markdown]
# MÓDULO 3: DICCIONARIOS 3 Actualiza la información de nuestro diccionario llamado :
#
# mi_dic
#
# (reasignando nuevos valores a las claves según corresponda), y agrega una nueva clave llamada "pais" (sin tilde).
#
# Los nuevos datos son:
#
# nombre: Karen
#
# apellido: Jurgens
#
# edad: 36
#
# ocupacion: Editora
#
# pais: Colombia
# Para ello, no debes cambiar la línea de código ya escrita, sino actualizar los valores mediante métodos de diccionarios.

# %%
mi_dic = {'nombre': 'Karen', 'apellido': 'Jurgens', 'edad': 35, 'ocupacion':'periodista'}
mi_dic['pais'] = 'Colombia'
mi_dic['edad'] = 36
mi_dic['ocupacion'] = 'editora'
print(mi_dic)
# Out:
# {'nombre': 'Karen', 'apellido': 'Jurgens', 'edad': 36, 'ocupacion': 'editora', 'pais': 'Colombia'}

# %% [markdown]
# MÓDULO 3: TUPLAS 2 Convierte a lista la siguiente tupla, y almacénala en una variable llamad
# mi_lista.
#
# mi_tupla = (1, 2, 3, 2, 3, 1, 3, 2)

# %%
mi_tupla = (1, 2, 3, 2, 3, 1, 3, 2)
mi_lista = list(mi_tupla)
print(type(mi_tupla))
print(type(mi_lista))
# Out:
# <class 'tuple'>
# <class 'list'>

# %% [markdown]
# MÓDULO 3: TUPLAS 3 Extrae los elementos de la siguiente tupla en cuatro variables:
# a, b, c, d
#
# mi_tupla = (1, 2, 3, 4)

# %%
mi_tupla = (1, 2, 3, 4)
x, y, z, w = mi_tupla
print(x, y, z, w)
# Out:
# 1 2 3 4

# %% [markdown]
# MÓDULO 3: BOOLEANOS 2 Verifica si
#
# 17834/34
# es mayor que
#
# 87*56
# y muestra el resultado (booleano) en pantalla utilizando
#
# print()

# %%
numero1 = 17834/34
numero2 = 87 * 56
numero = (numero1 > numero2)
print(numero1, numero2)
print(numero)
# Out:
# 524.5294117647059 4872
# False

# %% [markdown]
# MÓDULO 3: SET 2

# %%
sorteo = {"Camila", "Margarita", "Axel", "Jorge", "Miguel", "Mónica"}
sorteo.pop()
print(sorteo)
# Out:
# {'Camila', 'Margarita', 'Jorge', 'Axel', 'Mónica'}

# %% [markdown]
# MÓDULO 3: SET 3

# %%
sorteo = {"Camila", "Margarita", "Axel", "Jorge", "Miguel", "Mónica"}
sorteo.add("Damián")
print(sorteo)
# Out:
# {'Miguel', 'Camila', 'Margarita', 'Jorge', 'Damián', 'Axel', 'Mónica'}

# %% [markdown]
# MÓDULO 4: SUBSTRINGS 2 Toma *cada tercer caracter empezando desde el noveno hasta el final de la frase, e imprime el resultado.
# "Nunca confíes en un ordenador que no puedas lanzar por una ventana"

# %%
texto = "Nunca confíes en un ordenador que no puedas lanzar por una ventana"
resultado = texto[8::3]
print(resultado)
# Out:
# neeuoed eoualz rnvta

# %% [markdown]
# MÓDULO 4: SUBSTRINGS 3

# %%
frase = "Es genial trabajar con ordenadores. No discuten, lo recuerdan todo y no se beben tu cerveza"
resultado = frase[::-1]
print(resultado)
# Out:
# azevrec ut nebeb es on y odot nadreucer ol ,netucsid oN .serodanedro noc rajabart laineg sE

# %% [markdown]
# MÓDULO 3: PRÁCTICA FINAL

# %%
texto = input("Ingrese un texto")

#Pasa el texto a minúsculas
texto = texto.lower()
letras= input("Ingrese tres letras separadas por espacio")

#separa las palabras por espacios
palabras = texto.split(" ")
print("El texto tiene" + " " + str(len(palabras)) + " " + "palabras")

#Saca la primera y última letra con los índices 
print("La primera letra del texto es " + " " + texto[0])
print("La última letra del texto es " + " " + texto[-1])

#Revierte el orden de la lista y une los elementos separados por un espacio
palabras.reverse()
palabras_reverse= " ".join(palabras)
print("El texto en orden invertido es:" + " " + palabras_reverse)

#Busca la palabra python
python_presente = texto.find("python")
if python_presente == 0:
    print("La palabra 'python' SÍ está presente en el texto")
else:
    print("La palabra 'python' NO está presente en el texto")

#Pasa las letras a minúscula
letras = letras.lower()

#separa las 3 letras por espacios
letras = letras.split(" ")

#almacena cada letra en una variable
letra1 = letras[0]
letra2 = letras[1]
letra3 = letras[2]


print(f"La letra {letra1} aparece: " + str(texto.count(letra1)) + " " + "veces")
print(f"La letra {letra2} aparece: " + str(texto.count(letra2)) + " " + "veces")
print(f"La letra {letra3} aparece: " + str(texto.count(letra3)) + " " + "veces")
